# %%
import pandas as pd

# %% [markdown]
# # broadcasting

# %%
nba = pd.read_csv('data/nba.csv')
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba['Age'] = nba['Age'] + 5
nba['Salary in million'] = round(nba['Salary'] / 1000_000)
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  30.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  30.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  32.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  27.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  34.0   6-10   231.0
#
#              College     Salary  Salary in million
# 0              Texas  7730337.0                8.0
# 1          Marquette  6796117.0                7.0
# 2  Boston University        NaN                NaN
# 3      Georgia State  1148640.0                1.0
# 4                NaN  5000000.0                5.0

# %% [markdown]
# # a review of value_count

# %%
nba['Team'].value_counts().head()
# Out:
# New Orleans Pelicans    19
# Memphis Grizzlies       18
# New York Knicks         16
# Milwaukee Bucks         16
# Boston Celtics          15
# Name: Team, dtype: int64

# %%
nba['Position'].value_counts().head(1)
# Out:
# SG    102
# Name: Position, dtype: int64

# %% [markdown]
# # drop null value

# %%
nba.tail(3)
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 455  Tibor Pleiss  Utah Jazz    21.0        C  31.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  31.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary  Salary in million
# 455  2900000.0                3.0
# 456   947276.0                1.0
# 457        NaN                NaN

# %%
# default to drop row which contains 1 or more null
nba.dropna(how='all', inplace=True)
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  30.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  30.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  32.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  27.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  34.0   6-10   231.0
#
#              College     Salary  Salary in million
# 0              Texas  7730337.0                8.0
# 1          Marquette  6796117.0                7.0
# 2  Boston University        NaN                NaN
# 3      Georgia State  1148640.0                1.0
# 4                NaN  5000000.0                5.0

# %%
nba.dropna(axis=1, how='all').head() # drop column contains null
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  30.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  30.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  32.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  27.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  34.0   6-10   231.0
#
#              College     Salary  Salary in million
# 0              Texas  7730337.0                8.0
# 1          Marquette  6796117.0                7.0
# 2  Boston University        NaN                NaN
# 3      Georgia State  1148640.0                1.0
# 4                NaN  5000000.0                5.0

# %%
nba.dropna(subset='Salary').head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  30.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  30.0    6-6   235.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  27.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  34.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  34.0    6-9   240.0
#
#          College      Salary  Salary in million
# 0          Texas   7730337.0                8.0
# 1      Marquette   6796117.0                7.0
# 3  Georgia State   1148640.0                1.0
# 4            NaN   5000000.0                5.0
# 5            NaN  12000000.0               12.0

# %% [markdown]
# # sort

# %%
nba.sort_values(['Team', 'Name'], ascending=[True, False], inplace=True)
nba
# Out:
#                  Name                Team  Number Position   Age Height  \
# 322    Walter Tavares       Atlanta Hawks    22.0        C  29.0    7-3
# 310  Tim Hardaway Jr.       Atlanta Hawks    10.0       SG  29.0    6-6
# 321    Tiago Splitter       Atlanta Hawks    11.0        C  36.0   6-11
# 320   Thabo Sefolosha       Atlanta Hawks    25.0       SF  37.0    6-7
# 315      Paul Millsap       Atlanta Hawks     4.0       PF  36.0    6-8
# ..                ...                 ...     ...      ...   ...    ...
# 374        JJ Hickson  Washington Wizards    21.0        C  32.0    6-9
# 380    Garrett Temple  Washington Wizards    17.0       SG  35.0    6-6
# 372       Drew Gooden  Washington Wizards    90.0       PF  39.0   6-10
# 369      Bradley Beal  Washington Wizards     3.0       SG  27.0    6-5
# 368     Alan Anderson  Washington Wizards     6.0       SG  38.0    6-6
#
#      Weight               College      Salary  Salary in million
# ...

# %% [markdown]
# # sort index

# %%
nba.sort_index()
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  30.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  30.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  32.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  27.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  34.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  25.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  31.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  29.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  31.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  31.0    7-0   231.0
#
#                College     Salary  Salary in million
# ...

# %% [markdown]
# # rank value

# %%
nba = pd.read_csv('data/nba.csv').dropna(how='all')
nba['Salary'] = nba['Salary'].fillna(0).astype('int')
nba['College'] = nba['College'].fillna('no college')
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 457 entries, 0 to 456
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   457 non-null    object
#  8   Salary    457 non-null    int64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 35.7+ KB

# %%
nba['Salary'].rank(ascending=False).astype('int')
# Out:
# 0       97
# 1      110
# 2      452
# 3      322
# 4      147
#       ...
# 452    250
# 453    241
# 454    383
# 455    214
# 456    367
# Name: Salary, Length: 457, dtype: int64

# %%
nba['Salary rank'] = nba['Salary'].rank(ascending=False).astype('int')
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College   Salary  Salary rank
# 0              Texas  7730337           97
# 1          Marquette  6796117          110
# 2  Boston University        0          452
# 3      Georgia State  1148640          322
# 4         no college  5000000          147

# %%
nba.sort_values('Salary', ascending=False).head(20)
# Out:
#                   Name                   Team  Number Position   Age Height  \
# 109        Kobe Bryant     Los Angeles Lakers    24.0       SF  37.0    6-6
# 169       LeBron James    Cleveland Cavaliers    23.0       SF  31.0    6-8
# 33     Carmelo Anthony        New York Knicks     7.0       SF  32.0    6-8
# 251      Dwight Howard        Houston Rockets    12.0        C  30.0   6-11
# 339         Chris Bosh             Miami Heat     1.0       PF  32.0   6-11
# 100         Chris Paul   Los Angeles Clippers     3.0       PG  31.0    6-0
# 414       Kevin Durant  Oklahoma City Thunder    35.0       SF  27.0    6-9
# 164       Derrick Rose          Chicago Bulls     1.0       PG  27.0    6-3
# 349        Dwyane Wade             Miami Heat     3.0       SG  34.0    6-4
# 174         Kevin Love    Cleveland Cavaliers     0.0       PF  27.0   6-10
# 98      DeAndre Jordan   Los Angeles Clippers     6.0        C  27.0   6-11
# ...
